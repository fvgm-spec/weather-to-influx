# %%
import sys
sys.path.append('..')

from src.weather_collector import WeatherCollector

# %%
collector = WeatherCollector()
cities = ["London", "New York", "Tokyo"]

# %%
for city in cities:
    data = collector.get_weather(city)
    print(data)
# Out:
# Error fetching data for London: Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.
# None
# Error fetching data for New York: Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.
# None
# Error fetching data for Tokyo: Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.
# None

# %%
from influxdb_client_3 import InfluxDBClient3, Point
influx_host = 'http://localhost:8086'
database = 'INFLUXDB_DATABASE', 'weather_data'
client = InfluxDBClient3(host=influx_host,database=database)

# %%
point = Point("measurement").tag("location", "london").field("temperature", 42)
client.write(point)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/weather-to-influx/influx_env/lib/python3.11/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~/weather-to-influx/influx_env/lib/python3.11/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...

# %%
collector = WeatherCollector()
cities = ["London", "New York", "Tokyo"]

for city in cities:
    try:
        data = collector.get_weather(city)
        # if data:
        #     collector.write_to_influx(data)
    except Exception as e:
        print(f"Error collecting data for {city}: {e}")
